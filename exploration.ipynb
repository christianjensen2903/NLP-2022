# %%
negative = [('*PLAINTEXT* stallion', -1.66543911577155), ('*PLAINTEXT* Namchul', -1.2890499587339164), ('*QUESTION* American', -1.2138400136826477), ('*PLAINTEXT* Mahlon', -1.1265955202489868), ('*PLAINTEXT* impressionable', -1.1240816481257647), ('*PLAINTEXT* Of', -0.9935149915557098), ('*PLAINTEXT* hazard', -0.950250692189865), ('*EUCLIDEAN*', -0.9419746942008256), ('*PLAINTEXT* Georgetown', -0.903986836182355), ('*PLAINTEXT* performances', -0.8983830194823449), ('*PLAINTEXT* 5–1', -0.8447410634228282),
            ('*PLAINTEXT* testimony', -0.8180048400072809), ('*PLAINTEXT* leap', -0.8149484752454671), ('*QUESTION* domain', -0.8069761504363033), ('*PLAINTEXT* ð', -0.8036538264573103), ('*PLAINTEXT* sect', -0.7919558945463677), ('*PLAINTEXT* twenty', -0.7881978247475091), ('*PLAINTEXT* 82,304', -0.7763533848659432), ('*PLAINTEXT* optimum', -0.7605170320439848), ('*PLAINTEXT* animée', -0.7485009801325516), ('*QUESTION* awards', -0.7411073990238304), ('*PLAINTEXT* unicameral', -0.7315278706899753), ('*COSINE*', -0.7296697886522784),  ('*PLAINTEXT* Freemasons', -0.7279219394656506), ('*PLAINTEXT* Suspended', -0.7270952539999632)]
positive = [('*OVERLAP*', 1.53655056180642), ('*PLAINTEXT* arrest', 1.2126413195367138), ('*PLAINTEXT* co-owned', 1.0340129678249823), ('*PLAINTEXT* 48cm', 0.9250752513115662), ('*PLAINTEXT* particular', 0.9101900869403766), ('*PLAINTEXT* /əˈnɒfɪliːz/', 0.8979329061139683), ('*PLAINTEXT* drained', 0.8848510575490889), ('*PLAINTEXT* Diaspora', 0.8841832296989955), ('*PLAINTEXT* Immediate', 0.8820263126212537), ('*PLAINTEXT* then-party', 0.8769981452097579), ('*PLAINTEXT* Starret', 0.8457295880298914), ('*PLAINTEXT* Spinach', 0.8396449533556577), ('*PLAINTEXT* unafraid', 0.8377918594506482), ('*PLAINTEXT* homeplace', 0.8294207787335621), ('*PLAINTEXT* 1560', 0.8058991610929575), ('*PLAINTEXT* al-qaly', 0.7849013700340053), ('*PLAINTEXT* 40°C', 0.7848578731315871), ('*PLAINTEXT* demographer', 0.7773122864208342), ('*PLAINTEXT* aeroplanes', 0.7739068605300615), ('*PLAINTEXT* exothermic', 0.7732698232841289), ('*PLAINTEXT* columnist', 0.7697962540519487), ('*PLAINTEXT* TR-63', 0.7618370102270735), ('*PLAINTEXT* kýtos', 0.7353529948205116), ('*PLAINTEXT* Biscayne', 0.730043383742636), ('*PLAINTEXT* blood', 0.7187224652479756)]

# %%
# Make two barcharts in one figure. One for negative and one for positive.
# One the x-axis should be the feature names
# One the y-axis should be the feature weights
# The negative features should be in red and the positive features in blue
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10, 10))
plt.subplot(2, 1, 1)
plt.bar(np.arange(len(negative)), [x[1] for x in negative], color='red')
plt.xticks(np.arange(len(negative)), [f'{i+1} {x[0]}' for i, x in enumerate(negative)], rotation=90)
plt.title('Negative Features')
# Create more space between the two subplots
plt.subplots_adjust(hspace=1)
plt.subplot(2, 1, 2)
plt.bar(np.arange(len(positive)), [x[1] for x in positive], color='blue')
plt.xticks(np.arange(len(positive)), [f'{i} {x[0]}' for i, x in enumerate(positive)], rotation=90)
plt.title('Positive Features')
plt.show()
